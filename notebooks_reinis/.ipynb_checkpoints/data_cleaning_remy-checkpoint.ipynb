# %%
import pandas as pd
import numpy as np
from scipy.stats import zscore
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
sns.set(rc={'figure.figsize':(25,10)})

# %%
# This is a function definition in Python that takes two arguments: `filename` and `new_filename`, both of which are strings. 
# The function reads the content of an Excel file using the pandas library's `read_excel` function and stores it in a dataframe object. 
# It then writes the contents of the dataframe object to a CSV file using the `to_csv` function,
# with the `index` parameter set to `None` and `header` parameter set to `True`. 
# The function returns `None`. This function can be used to convert an Excel file to a CSV file.

def transform_xls_to_csv(filename: str, new_filename: str) -> None:
    # Read and store content of an excel file 
    read_file = pd.read_excel (filename)
    # Write the dataframe object into csv file
    read_file.to_csv (new_filename, index = None, header=True)

# %%
transform_xls_to_csv('../raw_data/bookings_whithout_onepark.xlsx', '../raw_data/bookings_without_onepark.csv')

# %%
# This code reads a CSV file named "bookings_without_onepark.csv" located in the "../raw_data/" 
# directory and stores the data in a pandas DataFrame called "df". The "dtype" parameter specifies
# the data types of the columns in the DataFrame, which are defined in a custom dictionary 
# called "custom_dtype". The "parse_dates" parameter specifies which columns should be parsed as datetime objects.
# In this case, the columns "creation_date_hour", "beginning_date_hour", and "end_date_hour" are being parsed as datetime objects.
df = pd.read_csv("../raw_data/bookings_without_onepark.csv", 
                  
                 parse_dates=['creation_date_hour','beginning_date_hour', 'end_date_hour'])
# Out:
# /var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/ipykernel_79484/1042825735.py:6: DtypeWarning: Columns (1,14,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../raw_data/bookings_without_onepark.csv",

# %%
# Check for nan values and transform them to unknown to count them and to 0 after
df = df.fillna('unknown')
df.isin(['unknown']).sum()
df.replace({'unknown': 0})
# Out:
#               id      pocket product     status    option    guest_id  \
# 0        5144307          36     H10   finished  standard  DCL0300508
# 1        5144312         781     H10   finished  standard  DCL0266680
# 2        5144315         491     H10   finished  standard  DCL0286500
# 3        5144319      600287     H10   finished  standard  DCL0254021
# 4        5144320      600287     H10   canceled  standard  DCL0271067
# ...          ...         ...     ...        ...       ...         ...
# 536169  10276847  0000500287    F397  completed  standard  DCL0129618
# 536170  10276859  0000000781    F398  completed  standard  DCL0779147
# 536171  10276871  0000000206    F397  completed  standard  DCL0524194
# 536172  10276885  0000000206     H10  completed  standard  DCL0311148
# 536173  10276914  0000000036    F150  completed  standard  DCL0669147
#
#         booking_fees  amount  total_amount  discount  ... begining_slice  \
# 0                1.0    58.2         59.20      0.00  ...      15H à 18H
# 1                3.0    29.5         32.50      0.00  ...        6H à 9H
# 2                3.5    28.8         23.04      9.26  ...        6H à 9H
# 3                4.0    40.0         44.00      0.00  ...        0H à 6H
# 4                4.0    56.0         60.00      0.00  ...      12H à 15H
# ...              ...     ...           ...       ...  ...            ...
# 536169           0.0    46.5         46.50      0.00  ...        6H à 9H
# 536170           0.0    46.0         46.00      0.00  ...        0H à 6H
# 536171           0.0    29.9         29.90      0.00  ...      15H à 18H
# 536172           0.0    56.9         56.90      0.00  ...      12H à 15H
# 536173           0.0     5.0          5.00      0.00  ...      18H à 24H
#
#                  end_date_hour            max_date_hour  \
# 0      2019-02-10 19:44:59.999                        0
# 1      2019-01-10 21:30:00.000                        0
# 2      2019-01-04 21:45:00.000                        0
# 3      2019-02-02 17:45:00.000                        0
# 4      2019-01-20 15:59:59.999                        0
# ...                        ...                      ...
# 536169 2023-06-26 17:15:00.000  2023-06-27 07:44:59.999
# 536170 2023-07-10 05:29:59.999  2023-07-11 05:29:59.999
# 536171 2023-06-25 23:29:59.999  2023-06-26 11:59:00.000
# 536172 2023-06-21 22:44:59.999  2023-06-22 02:45:00.000
# 536173 2023-06-19 23:29:59.999  2023-06-20 00:00:00.000
#
#                   cxl_date_hour          los lead_time_hours entry_date_hour  \
# 0                             0         +24h      893.816389               0
# 1                             0         +24h      165.958611               0
# 2                             0         +24h       20.745278               0
# 3                             0         +24h      715.766944               0
# 4       2019-01-11 18:26:00.000         +24h      386.513056               0
# ...                         ...          ...             ...             ...
# 536169                        0         +24h      104.460000               0
# 536170                        0         +24h      366.131667               0
# 536171                        0         +24h      112.496111               0
# 536172                        0         +24h       15.133889               0
# 536173                        0  00:30 06:00       18.501667               0
#
#         exit_date_hour        promo_code amount_promo
# 0                    0                 0         0.00
# 1                    0                 0         0.00
# 2                    0  VOYAGEURVACANCES         9.26
# 3                    0                 0         0.00
# 4                    0                 0         0.00
# ...                ...               ...          ...
# 536169               0                 0         0.00
# 536170               0                 0         0.00
# 536171               0                 0         0.00
# 536172               0                 0         0.00
# 536173               0                 0         0.00
#
# [536174 rows x 22 columns]

# %%
## NOT NEEDED RIGHT NOW ##

# Compute Z scores 
df['z_score_booking_fees'] = zscore(df['booking_fees'])
df['z_score_amount'] = zscore(df['amount'])
df['z_score_total_amount'] = zscore(df['total_amount'])
df['z_score_discount'] = zscore(df['discount'])

# Find outliers
outliers = df[abs(df['z_score_booking_fees']) > 3]

print(outliers)
print(len(outliers))
# Out:
#               id      pocket product     status   option    guest_id  \
# 32564    5497261      100435     H10   finished  premium  DCL0051721
# 32741    5498845      100435     H10   finished  premium  DCL0382375
# 33060    5501611      100435     H10   finished  premium  DCL0382118
# 33066    5501688      100435     H10   finished  premium  DCL0382764
# 33436    5505401      100435     H10   finished  premium  DCL0313253
# ...          ...         ...     ...        ...      ...         ...
# 535771  10273459  0000000025    F398  completed  premium  DCL0880274
# 535811  10273802  0000000025     H10  completed  premium  DCL0682660
# 536018  10275752  0000100435    F398  completed  premium  DCL0097916
# 536043  10275903  0000100435    F398  completed  premium  DCL0248992
# 536081  10276221  0000000025     H10  completed  premium  DCL0887448
#
#         booking_fees  amount  total_amount  discount  ...          los  \
# 32564            9.0    14.9          23.9       0.0  ...  06:00 24:00
# 32741            9.0    46.5          55.5       0.0  ...         +24h
# 33060            9.0    86.0          95.0       0.0  ...         +24h
# 33066            9.0     4.0          13.0       0.0  ...  00:30 06:00
# 33436            9.0    30.7          39.7       0.0  ...         +24h
# ...              ...     ...           ...       ...  ...          ...
# 535771           9.0    68.0          77.0       0.0  ...         +24h
# 535811           9.0    12.7          21.7       0.0  ...  06:00 24:00
# 536018          12.0    59.0          71.0       0.0  ...         +24h
# 536043          12.0    59.0          71.0       0.0  ...         +24h
# 536081           9.0    17.6          26.6       0.0  ...  06:00 24:00
#
#        lead_time_hours entry_date_hour exit_date_hour promo_code amount_promo  \
# 32564        13.006944         unknown        unknown    unknown      unknown
# 32741       743.125833         unknown        unknown    unknown      unknown
# 33060        22.526389         unknown        unknown    unknown      unknown
# 33066       216.591944         unknown        unknown    unknown      unknown
# 33436       260.815278         unknown        unknown    unknown      unknown
# ...                ...             ...            ...        ...          ...
# 535771       41.383333         unknown        unknown    unknown      unknown
# 535811       37.571111         unknown        unknown    unknown      unknown
# 536018       14.920278         unknown        unknown    unknown      unknown
# 536043       14.038611         unknown        unknown    unknown      unknown
# 536081       11.352778         unknown        unknown    unknown      unknown
#
#        z_score_booking_fees  z_score_amount z_score_total_amount  \
# 32564              3.056448       -0.979970            -0.638211
# 32741              3.056448        0.359108             0.720355
# 33060              3.056448        2.032956             2.418563
# 33066              3.056448       -1.441867            -1.106831
# 33436              3.056448       -0.310431             0.041072
# ...                     ...             ...                  ...
# 535771             3.056448        1.270190             1.644696
# 535811             3.056448       -1.073197            -0.732795
# 536018             4.311877        0.888807             1.386741
# 536043             4.311877        0.888807             1.386741
# 536081             3.056448       -0.865555            -0.522131
#
#        z_score_discount
# 32564         -0.249314
# 32741         -0.249314
# 33060         -0.249314
# 33066         -0.249314
# 33436         -0.249314
# ...                 ...
# 535771        -0.249314
# 535811        -0.249314
# 536018        -0.249314
# 536043        -0.249314
# 536081        -0.249314
#
# [7513 rows x 26 columns]
# 7513

# %%
plt.figure()
plt.boxplot(df['booking_fees'].dropna())
plt.title('Box Plot de Booking Fees')
plt.show()

# %%
sns.boxplot(x=df['booking_fees'])
plt.title('Box Plot de Booking Fees')
plt.show()

# %%
# Creation of a dataframe with 1 entry for each day
dates = pd.date_range(start='2021-06-01', end='2023-06-20')
df_jours = pd.DataFrame(dates, columns=['date'])
df_jours['nb_entries'] = 0

# %%
df_jours.head()
# Out:
#         date  nb_entries
# 0 2021-06-01           0
# 1 2021-06-02           0
# 2 2021-06-03           0
# 3 2021-06-04           0
# 4 2021-06-05           0

# %%
# This code is iterating through each row of a DataFrame `df` and for each row, 
# it is extracting the values of the columns 'beginning_date_hour' and 'end_date_hour' 
# and storing them in variables `start` and `end` respectively.
for _, row in df.iterrows():
    start = row['beginning_date_hour']
    end = row['end_date_hour']
    df_jours.loc[(df_jours['date'] >= start) & (df_jours['date'] <= end), 'nb_entries'] += 1

# %%
df_jours.head()
# Out:
#         date  nb_entries
# 0 2021-06-01         398
# 1 2021-06-02         429
# 2 2021-06-03         454
# 3 2021-06-04         437
# 4 2021-06-05         744

# %%
# Save the df to csv 
#df_jours.to_csv("../prepared_data/01_06_2021_to_20_06_2023.csv", index=False)

# %%
# Création du line plot
sns.lineplot(x='date', y='nb_entries', data=df_jours)

# Définition du titre du graphique
plt.title('Number of entries per day')

# Affichage du graphique
plt.show()

# %%
## NOT NEEDED RIGHT NOW, JUST EDA ##

# Filtrez le DataFrame pour ne garder que les colonnes numériques
numeric_cols = df.select_dtypes(include=[np.number])

# Calculez la matrice de corrélation
corr_matrix = numeric_cols.corr()

# Affichez la heatmap
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
## TEST FOR NEXT STEP ##
# This code prepares the data for a SARIMAX model by grouping 
# the data by date and calculating the total number of sales and statistics 
# for the exogenous variables. It also fills any missing values with 0 and 
# checks if the index is of type datetime. Finally, it sorts the data by date.

# Préparation des données pour le modèle SARIMAX
df['date'] = df['beginning_date_hour'].dt.date

# Regroupement par 'date' et calcul du nombre total de places vendues et des statistiques pour les variables exogènes
daily_data = df.groupby('date').agg({
    'id':'size', 
    'amount':'mean', 
    'amount_promo':'mean', 
    'booking_fees': 'mean',
    'discount': 'mean'}) 

daily_data.rename(columns={'id':'total_sales'}, inplace=True)

daily_data = daily_data.fillna(0) # cas de amount_promo

# Check if index est de type datetime
daily_data.index = pd.to_datetime(daily_data.index)

# Tri par date
daily_data.sort_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1587, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1586 try:
# -> 1587     result = self.grouper._cython_operation(
#    1588         "aggregate", values, how, axis=data.ndim - 1, min_count=min_count
#    1589     )
#    1590 except NotImplementedError:
#    1591     # generally if we have numeric_only=False
#    1592     # and non-applicable functions
#    1593     # try to python agg
#    1594     # TODO: shouldn't min_count matter?
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/groupby/ops.py:939, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     938 ngroups = self.ngroups
# --> 939 return cy_op.cython_operation(
#     940     values=values,
#     941     axis=axis,
#     942     min_count=min_count,
#     943     comp_ids=ids,
#     944     ngroups=ngroups,
#     945     **kwargs,
#     946 )
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/groupby/ops.py:626, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     618     return self._ea_wrap_cython_operation(
#     619         values,
#     620         min_count=min_count,
#    (...)
#     623         **kwargs,
#     624     )
# --> 626 return self._cython_op_ndim_compat(
#     627     values,
#     628     min_count=min_count,
#     629     ngroups=ngroups,
#     630     comp_ids=comp_ids,
#     631     mask=None,
#     632     **kwargs,
#     633 )
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/groupby/ops.py:451, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     450     result_mask = result_mask[None, :]
# --> 451 res = self._call_cython_op(
#     452     values2d,
#     453     min_count=min_count,
#     454     ngroups=ngroups,
#     455     comp_ids=comp_ids,
#     456     mask=mask,
#     457     result_mask=result_mask,
#     458     **kwargs,
#     459 )
#     460 if res.shape[0] == 1:
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/groupby/ops.py:516, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     515 out_shape = self._get_output_shape(ngroups, values)
# --> 516 func, values = self.get_cython_func_and_vals(values, is_numeric)
#     517 out_dtype = self.get_out_dtype(values.dtype)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/groupby/ops.py:199, in WrappedCythonOp.get_cython_func_and_vals(self, values, is_numeric)
#     197     return func, values
# --> 199 func = self._get_cython_function(kind, how, values.dtype, is_numeric)
#     201 if values.dtype.kind in ["i", "u"]:
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/groupby/ops.py:164, in WrappedCythonOp._get_cython_function(cls, kind, how, dtype, is_numeric)
#     162 if "object" not in f.__signatures__:
#     163     # raise NotImplementedError here rather than TypeError later
# --> 164     raise NotImplementedError(
#     165         f"function is not implemented for this dtype: "
#     166         f"[how->{how},dtype->{dtype_str}]"
#     167     )
#     168 return f
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In [13], line 11
#       8 df['date'] = df['beginning_date_hour'].dt.date
#      10 # Regroupement par 'date' et calcul du nombre total de places vendues et des statistiques pour les variables exogènes
# ---> 11 daily_data = df.groupby('date').agg({
#      12     'id':'size',
#      13     'amount':'mean',
#      14     'amount_promo':'mean',
#      15     'booking_fees': 'mean',
#      16     'discount': 'mean'})
#      18 daily_data.rename(columns={'id':'total_sales'}, inplace=True)
#      20 daily_data = daily_data.fillna(0) # cas de amount_promo
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/groupby/generic.py:869, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     866 func = maybe_mangle_lambdas(func)
#     868 op = GroupByApply(self, func, args, kwargs)
# --> 869 result = op.agg()
#     870 if not is_dict_like(func) and result is not None:
#     871     return result
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/apply.py:168, in Apply.agg(self)
#     165     return self.apply_str()
#     167 if is_dict_like(arg):
# --> 168     return self.agg_dict_like()
#     169 elif is_list_like(arg):
#     170     # we require a list, but not a 'str'
#     171     return self.agg_list_like()
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/apply.py:481, in Apply.agg_dict_like(self)
#     478     results = {key: colg.agg(how) for key, how in arg.items()}
#     479 else:
#     480     # key used for column selection and output
# --> 481     results = {
#     482         key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     483     }
#     485 # set the final keys
#     486 keys = list(arg.keys())
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/apply.py:482, in <dictcomp>(.0)
#     478     results = {key: colg.agg(how) for key, how in arg.items()}
#     479 else:
#     480     # key used for column selection and output
#     481     results = {
# --> 482         key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     483     }
#     485 # set the final keys
#     486 keys = list(arg.keys())
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/groupby/generic.py:265, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     262     kwargs = {}
#     264 if isinstance(func, str):
# --> 265     return getattr(self, func)(*args, **kwargs)
#     267 elif isinstance(func, abc.Iterable):
#     268     # Catch instances of lists / tuples
#     269     # but not the class list / tuple itself.
#     270     func = maybe_mangle_lambdas(func)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1965, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    1963     return self._numba_agg_general(sliding_mean, engine_kwargs, "groupby_mean")
#    1964 else:
# -> 1965     result = self._cython_agg_general(
#    1966         "mean",
#    1967         alt=lambda x: Series(x).mean(numeric_only=numeric_only_bool),
#    1968         numeric_only=numeric_only_bool,
#    1969     )
#    1970     return result.__finalize__(self.obj, method="groupby")
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1601, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count)
#    1597     return result
#    1599 # TypeError -> we may have an exception in trying to aggregate
#    1600 #  continue and exclude the block
# -> 1601 new_mgr = data.grouped_reduce(array_func, ignore_failures=True)
#    1603 if not is_ser and len(new_mgr) < len(data):
#    1604     warn_dropping_nuisance_columns_deprecated(type(self), how)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/internals/base.py:199, in SingleDataManager.grouped_reduce(self, func, ignore_failures)
#     193 """
#     194 ignore_failures : bool, default False
#     195     Not used; for compatibility with ArrayManager/BlockManager.
#     196 """
#     198 arr = self.array
# --> 199 res = func(arr)
#     200 index = default_index(len(res))
#     202 mgr = type(self).from_array(res, index)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1595, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1587     result = self.grouper._cython_operation(
#    1588         "aggregate", values, how, axis=data.ndim - 1, min_count=min_count
#    1589     )
#    1590 except NotImplementedError:
#    1591     # generally if we have numeric_only=False
#    1592     # and non-applicable functions
#    1593     # try to python agg
#    1594     # TODO: shouldn't min_count matter?
# -> 1595     result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1597 return result
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1549, in GroupBy._agg_py_fallback(self, values, ndim, alt)
#    1544     ser = df.iloc[:, 0]
#    1546 # We do not get here with UDFs, so we know that our dtype
#    1547 #  should always be preserved by the implemented aggregations
#    1548 # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1549 res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1551 if isinstance(values, Categorical):
#    1552     # Because we only get here with known dtype-preserving
#    1553     #  reductions, we cast back to Categorical.
#    1554     # TODO: if we ever get "rank" working, exclude it here.
#    1555     res_values = type(values)._from_sequence(res_values, dtype=values.dtype)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/groupby/ops.py:981, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     978     preserve_dtype = True
#     980 else:
# --> 981     result = self._aggregate_series_pure_python(obj, func)
#     983 npvalues = lib.maybe_convert_objects(result, try_float=False)
#     984 if preserve_dtype:
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/groupby/ops.py:1005, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1003 for i, group in enumerate(splitter):
#    1004     group = group.__finalize__(obj, method="groupby")
# -> 1005     res = func(group)
#    1006     res = libreduction.extract_result(res)
#    1008     if not initialized:
#    1009         # We only do this validation on the first iteration
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1967, in GroupBy.mean.<locals>.<lambda>(x)
#    1963     return self._numba_agg_general(sliding_mean, engine_kwargs, "groupby_mean")
#    1964 else:
#    1965     result = self._cython_agg_general(
#    1966         "mean",
# -> 1967         alt=lambda x: Series(x).mean(numeric_only=numeric_only_bool),
#    1968         numeric_only=numeric_only_bool,
#    1969     )
#    1970     return result.__finalize__(self.obj, method="groupby")
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/generic.py:11124, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11106 @doc(
#   11107     _num_doc,
#   11108     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11122     **kwargs,
#   11123 ):
# > 11124     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/generic.py:10694, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10686 def mean(
#   10687     self,
#   10688     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   10692     **kwargs,
#   10693 ) -> Series | float:
# > 10694     return self._stat_function(
#   10695         "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10696     )
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/generic.py:10646, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10636     warnings.warn(
#   10637         "Using the level keyword in DataFrame and Series aggregations is "
#   10638         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   10641         stacklevel=find_stack_level(),
#   10642     )
#   10643     return self._agg_by_level(
#   10644         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   10645     )
# > 10646 return self._reduce(
#   10647     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10648 )
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/series.py:4471, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4467     raise NotImplementedError(
#    4468         f"Series.{name} does not implement {kwd_name}."
#    4469     )
#    4470 with np.errstate(all="ignore"):
# -> 4471     return op(delegate, skipna=skipna, **kwds)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/nanops.py:93, in disallow.__call__.<locals>._f(*args, **kwargs)
#      91 try:
#      92     with np.errstate(invalid="ignore"):
# ---> 93         return f(*args, **kwargs)
#      94 except ValueError as e:
#      95     # we want to transform an object array
#      96     # ValueError message to the more typical TypeError
#      97     # e.g. this is normally a disallowed function on
#      98     # object arrays that contain strings
#      99     if is_object_dtype(args[0]):
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     153         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154 else:
# --> 155     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 return result
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/nanops.py:410, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     407 if datetimelike and mask is None:
#     408     mask = isna(values)
# --> 410 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     412 if datetimelike:
#     413     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/nanops.py:698, in nanmean(values, axis, skipna, mask)
#     695     dtype_count = dtype
#     697 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 698 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     700 if axis is not None and getattr(the_sum, "ndim", False):
#     701     count = cast(np.ndarray, count)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/numpy/core/_methods.py:48, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
# ---> 48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
# La série temporelle
daily_data.index = pd.to_datetime(daily_data.index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [18], line 2
#       1 # La série temporelle
# ----> 2 daily_data.index = pd.to_datetime(daily_data.index)
#
# NameError: name 'daily_data' is not defined

# %%
daily_data.drop

# %%
# Définir la fréquence (ici quotidienne)
daily_data = daily_data.asfreq('D')
# Décomposition saisonnière pour déterminer la saisonnalité (si présente)
decomposition = sm.tsa.seasonal_decompose(daily_data, model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# # Prophet model

# %%
from prophet import Prophet

# %%
df_jours.head()
# Out:
#         date  nb_entries
# 0 2021-06-01         398
# 1 2021-06-02         429
# 2 2021-06-03         454
# 3 2021-06-04         437
# 4 2021-06-05         744

# %%
df_jours = df_jours.rename(columns={'date': 'ds', 'nb_entries': 'y'})
df_jours.head()
# Out:
#           ds    y
# 0 2021-06-01  398
# 1 2021-06-02  429
# 2 2021-06-03  454
# 3 2021-06-04  437
# 4 2021-06-05  744

# %%
df_jours
# Out:
#             ds     y
# 0   2021-06-01   398
# 1   2021-06-02   429
# 2   2021-06-03   454
# 3   2021-06-04   437
# 4   2021-06-05   744
# ..         ...   ...
# 745 2023-06-16  1549
# 746 2023-06-17  1970
# 747 2023-06-18  2240
# 748 2023-06-19  1383
# 749 2023-06-20  1559
#
# [750 rows x 2 columns]

# %%
train = df_jours.iloc[:525]

test = df_jours.iloc[525:]

# %%
model = Prophet(seasonality_mode='multiplicative')

# %%
model.fit(train)
# Out:
# 14:26:25 - cmdstanpy - INFO - Chain [1] start processing
# 14:26:25 - cmdstanpy - INFO - Chain [1] done processing
# 14:26:25 - cmdstanpy - ERROR - Chain [1] error: terminated by signal 6 Unknown error: -6
# Optimization terminated abnormally. Falling back to Newton.
# 14:26:25 - cmdstanpy - INFO - Chain [1] start processing
# 14:26:25 - cmdstanpy - INFO - Chain [1] done processing
# 14:26:25 - cmdstanpy - ERROR - Chain [1] error: terminated by signal 6 Unknown error: -6
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/prophet/models.py:90, in CmdStanPyBackend.fit(self, stan_init, stan_data, **kwargs)
#      89 try:
# ---> 90     self.stan_fit = self.model.optimize(**args)
#      91 except RuntimeError as e:
#      92     # Fall back on Newton
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/cmdstanpy/model.py:738, in CmdStanModel.optimize(self, data, seed, inits, output_dir, sig_figs, save_profile, algorithm, init_alpha, tol_obj, tol_rel_obj, tol_grad, tol_rel_grad, tol_param, history_size, iter, save_iterations, require_converged, show_console, refresh, time_fmt, timeout)
#     737     else:
# --> 738         raise RuntimeError(msg)
#     739 mle = CmdStanMLE(runset)
#
# RuntimeError: Error during optimization! Command '/Users/annettbehr/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin random seed=11481 data file=/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/tmpnv0zm1v8/d4mlq4me.json init=/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/tmpnv0zm1v8/wow870zq.json output file=/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/tmpnv0zm1v8/prophet_modelmsem4el8/prophet_model-20230625142625.csv method=optimize algorithm=lbfgs iter=10000' failed: console log output:
#
# dyld[80891]: Library not loaded: @rpath/libtbb.dylib
#   Referenced from: <4E041AEC-0C2B-312D-A4CD-CBED369E84C0> /Users/annettbehr/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin
#   Reason: tried: '/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS@rpath/libtbb.dylib' (no such file), '/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-a ...
#
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In [25], line 1
# ----> 1 model.fit(train)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/prophet/forecaster.py:1181, in Prophet.fit(self, df, **kwargs)
#    1179     self.params = self.stan_backend.sampling(stan_init, dat, self.mcmc_samples, **kwargs)
#    1180 else:
# -> 1181     self.params = self.stan_backend.fit(stan_init, dat, **kwargs)
#    1183 self.stan_fit = self.stan_backend.stan_fit
#    1184 # If no changepoints were requested, replace delta with 0s
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/prophet/models.py:97, in CmdStanPyBackend.fit(self, stan_init, stan_data, **kwargs)
#      95     logger.warning('Optimization terminated abnormally. Falling back to Newton.')
#      96     args['algorithm'] = 'Newton'
# ---> 97     self.stan_fit = self.model.optimize(**args)
#      98 params = self.stan_to_dict_numpy(
#      99     self.stan_fit.column_names, self.stan_fit.optimized_params_np)
#     100 for par in params:
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/cmdstanpy/model.py:738, in CmdStanModel.optimize(self, data, seed, inits, output_dir, sig_figs, save_profile, algorithm, init_alpha, tol_obj, tol_rel_obj, tol_grad, tol_rel_grad, tol_param, history_size, iter, save_iterations, require_converged, show_console, refresh, time_fmt, timeout)
#     736         get_logger().warning(msg)
#     737     else:
# --> 738         raise RuntimeError(msg)
#     739 mle = CmdStanMLE(runset)
#     740 return mle
#
# RuntimeError: Error during optimization! Command '/Users/annettbehr/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin random seed=97424 data file=/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/tmpnv0zm1v8/846itrm3.json init=/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/tmpnv0zm1v8/3dq75o95.json output file=/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/tmpnv0zm1v8/prophet_modeleqg6xvf7/prophet_model-20230625142625.csv method=optimize algorithm=newton iter=10000' failed: console log output:
#
# dyld[80892]: Library not loaded: @rpath/libtbb.dylib
#   Referenced from: <4E041AEC-0C2B-312D-A4CD-CBED369E84C0> /Users/annettbehr/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin
#   Reason: tried: '/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS@rpath/libtbb.dylib' (no such file), '/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-arm64-cpython-310/prophet/stan_model/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb/libtbb.dylib' (no such file), '/private/var/folders/pb/9zf7b0tn0mb1tqgmqhq_2j680000gn/T/pip-install-sy7aatf8/prophet_de533732d45641089984008eca7a92c9/build/lib.macosx-13.2-a ...
