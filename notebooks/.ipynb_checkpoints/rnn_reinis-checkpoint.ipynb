# %% [markdown]
# # This notebook is based on the RNN recap by Dayus

# %%
from datetime import datetime
import random
import pandas as pd
import numpy as np

from sklearn.preprocessing import RobustScaler, MinMaxScaler
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.optimizers.legacy import Nadam
from tensorflow.keras.layers import LSTM, Dense, Dropout, InputLayer, Masking
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers, regularizers
from keras.callbacks import EarlyStopping

# %%
sns.set_theme(rc={'figure.figsize':(16,8)})

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
# Load booking dataset
df_bookings = pd.read_csv("../prepared_data/01_06_2021_to_20_06_2023_anais.csv", parse_dates=[0], index_col=[0])

# %%
df_bookings
# Out:
#             nb_cars  nb_cars_cxl  nb_bookings  nb_bookings_cxl
# date
# 2021-06-01      368           30          172               12
# 2021-06-02      395           34          169                4
# 2021-06-03      428           26          170               13
# 2021-06-04      412           25          424               30
# 2021-06-05      695           49          187               16
# ...             ...          ...          ...              ...
# 2023-06-16     1450           99         1070               58
# 2023-06-17     1858          112          583               37
# 2023-06-18     2119          121          268               12
# 2023-06-19     1299           84          846               59
# 2023-06-20     1460           99          472               31
#
# [750 rows x 4 columns]

# %%
# Load product dataset
df_products = pd.read_csv("../prepared_data/01_06_2021_to_20_06_2023_products_anais.csv", parse_dates=[0], index_col=[0])

# %%
df_products
# Out:
#             hourly rate  WE package  1 week package  1 month package  \
# date
# 2021-06-01          115          14             176               53
# 2021-06-02          160           1             171               55
# 2021-06-03          178           0             189               52
# 2021-06-04          150           0             205               48
# 2021-06-05          204         236             199               45
# ...                 ...         ...             ...              ...
# 2023-06-16          571         239             435              178
# 2023-06-17          261        1018             378              175
# 2023-06-18          337        1199             385              172
# 2023-06-19          202         480             422              174
# 2023-06-20          702          77             476              177
#
#             other package  2 weeks package
# date
# 2021-06-01              5                5
# 2021-06-02              3                5
# 2021-06-03              4                5
# 2021-06-04              3                6
# 2021-06-05              3                8
# ...                   ...              ...
# 2023-06-16              0               27
# 2023-06-17              0               26
# 2023-06-18              2               24
# 2023-06-19              0               21
# 2023-06-20              6               22
#
# [750 rows x 6 columns]

# %%
# Merging DataFrames
df = df_bookings.merge(df_products, left_index=True, right_index=True)
df
# Out:
#             nb_cars  nb_cars_cxl  nb_bookings  nb_bookings_cxl  hourly rate  \
# date
# 2021-06-01      368           30          172               12          115
# 2021-06-02      395           34          169                4          160
# 2021-06-03      428           26          170               13          178
# 2021-06-04      412           25          424               30          150
# 2021-06-05      695           49          187               16          204
# ...             ...          ...          ...              ...          ...
# 2023-06-16     1450           99         1070               58          571
# 2023-06-17     1858          112          583               37          261
# 2023-06-18     2119          121          268               12          337
# 2023-06-19     1299           84          846               59          202
# 2023-06-20     1460           99          472               31          702
#
#             WE package  1 week package  1 month package  other package  \
# date
# 2021-06-01          14             176               53              5
# 2021-06-02           1             171               55              3
# 2021-06-03           0             189               52              4
# 2021-06-04           0             205               48              3
# 2021-06-05         236             199               45              3
# ...                ...             ...              ...            ...
# 2023-06-16         239             435              178              0
# 2023-06-17        1018             378              175              0
# 2023-06-18        1199             385              172              2
# 2023-06-19         480             422              174              0
# 2023-06-20          77             476              177              6
#
#             2 weeks package
# date
# 2021-06-01                5
# 2021-06-02                5
# 2021-06-03                5
# 2021-06-04                6
# 2021-06-05                8
# ...                     ...
# 2023-06-16               27
# 2023-06-17               26
# 2023-06-18               24
# 2023-06-19               21
# 2023-06-20               22
#
# [750 rows x 10 columns]

# %%
# This function will create a slice of data from a specified random starting position. 
# The random position must be generated externally.

def get_Xi_yi(df_X, 
              df_y,
              random_start,
              X_length=28, 
              y_length=7):
    
#     must define a random_start:int for function to run
    Xi = df_X.iloc[random_start-X_length:random_start]
    yi = df_y.iloc[random_start:random_start+y_length]
    
    return Xi, yi

# %%
# The main data selection function. 
# This function will generate all random slices based on the length of the dataframe passed. 
# Important to note, if val state is set to true, it will only generate data slices after the val_cutoff point.

def get_X_y(df, 
            X_length=28, 
            y_length=7, 
            number_of_sequences=51, 
            number_of_targets=1, 
            n_pca=0.9, 
            val=False, 
            val_cutoff=0.8):
    
#     limit dataframes to length for train/test splits
    df_X = df.copy()
    df_y = df.iloc[:, :number_of_targets].copy()
    
#     convert and scale X dataframe to PCA to solve dimensionality problem
    scaler = MinMaxScaler()
    df_X_scaled = scaler.fit_transform(df_X)
    pca = PCA(n_components=n_pca).fit(df_X_scaled)
    df_X_proj = pd.DataFrame(pca.transform(df_X_scaled))
    df_X_proj.index = df_X.index
    
#     create unique list to sample random datapoints from
    if val:
        sample_list = list(range(int(len(df_y)*val_cutoff), int(len(df_y)-y_length)))
    if not val:
        sample_list = list(range(int(X_length), int(len(df_y)-y_length)))
    random.shuffle(sample_list)
    
#     empty lists to append data to, will create 3D dataframe here
    X, y = [], []
    
#     for loop to select ith values from data
    for i in range(number_of_sequences):
        Xi, yi = get_Xi_yi(df_X_proj, df_y, sample_list.pop(-1), X_length, y_length)
        X.append(Xi.values.tolist())
        y.append(yi.values.tolist())
        
    return np.array(X), np.array(y)

# %%
df.iloc[:int(len(df)*0.6)]
# Out:
#             nb_cars  nb_cars_cxl  nb_bookings  nb_bookings_cxl  hourly rate  \
# date
# 2021-06-01      368           30          172               12          115
# 2021-06-02      395           34          169                4          160
# 2021-06-03      428           26          170               13          178
# 2021-06-04      412           25          424               30          150
# 2021-06-05      695           49          187               16          204
# ...             ...          ...          ...              ...          ...
# 2022-08-20     1225           67          264               18          100
# 2022-08-21     1215           63          141                7           91
# 2022-08-22      893           52          294                8           63
# 2022-08-23      887           43          275               16          164
# 2022-08-24      938           47          274               22          258
#
#             WE package  1 week package  1 month package  other package  \
# date
# 2021-06-01          14             176               53              5
# 2021-06-02           1             171               55              3
# 2021-06-03           0             189               52              4
# 2021-06-04           0             205               48              3
# 2021-06-05         236             199               45              3
# ...                ...             ...              ...            ...
# 2022-08-20         349             498              227              2
# 2022-08-21         419             425              210             23
# 2022-08-22         179             410              199              1
# 2022-08-23          34             466              183              1
# 2022-08-24           4             469              168              2
#
#             2 weeks package
# date
# 2021-06-01                5
# 2021-06-02                5
# 2021-06-03                5
# 2021-06-04                6
# 2021-06-05                8
# ...                     ...
# 2022-08-20               49
# 2022-08-21               47
# 2022-08-22               41
# 2022-08-23               39
# 2022-08-24               37
#
# [450 rows x 10 columns]

# %%
# Define X_train, y_train
X_train, y_train = get_X_y(df.iloc[:int(len(df)*0.6)], 
                           X_length=56, 
                           y_length=7, 
                           number_of_sequences=50, 
                           number_of_targets=1)

# %%
y_train = y_train[:, :, 0]

# %%
print(X_train.shape, y_train.shape)
# Out:
# (50, 56, 6) (50, 7)

# %%
# Define X_val, y_val
X_val, y_val = get_X_y(df.iloc[:int(len(df)*0.8)], 
                       X_length=56, 
                       y_length=7, 
                       number_of_sequences=15, 
                       number_of_targets=1, 
                       val=True, 
                       val_cutoff=0.6)

# %%
y_val = y_val[:, :, 0]

# %%
print(X_val.shape, y_val.shape)
# Out:
# (15, 56, 6) (15, 7)

# %%
# Define X_test, y_tes
X_test, y_test = get_X_y(df.iloc[:int(len(df)*0.99)], 
                         X_length=56, 
                         y_length=7, 
                         number_of_sequences=15, 
                         number_of_targets=1, 
                         val=True, 
                         val_cutoff=0.8)

# %%
y_test = y_test[:, :, 0]

# %%
print(X_test.shape, y_test.shape)
# Out:
# (15, 56, 6) (15, 7)

# %%
df.describe()
# Out:
#            nb_cars  nb_cars_cxl  nb_bookings  nb_bookings_cxl  hourly rate  \
# count   750.000000   750.000000   750.000000       750.000000   750.000000
# mean   1140.521333   100.865333   426.333333        36.454667   315.601333
# std     418.860198    78.975308   217.368583        37.515426   169.882720
# min     364.000000    25.000000    54.000000         3.000000    59.000000
# 25%     835.500000    59.000000   247.000000        18.000000   183.500000
# 50%    1084.500000    80.000000   397.000000        27.000000   271.000000
# 75%    1401.500000   112.000000   548.750000        40.000000   423.750000
# max    2848.000000   752.000000  1243.000000       507.000000   988.000000
#
#         WE package  1 week package  1 month package  other package  \
# count   750.000000      750.000000       750.000000      750.00000
# mean    258.121333      408.444000       131.988000        3.32000
# std     323.391358      180.211881        53.751752        5.15309
# min       0.000000      131.000000        38.000000        0.00000
# 25%      17.000000      299.000000        89.000000        0.00000
# 50%     110.500000      373.000000       132.000000        1.00000
# 75%     388.750000      454.750000       161.000000        5.00000
# max    1536.000000     1405.000000       320.000000       33.00000
#
#        2 weeks package
# count       750.000000
# mean         23.046667
# std          10.025293
# min           2.000000
# 25%          16.000000
# 50%          22.000000
# 75%          27.000000
# max          55.000000

# %%
plt.hist(df['nb_cars']);

# %%
# To reduce skewness we will use a log transformations

# %%
# y normalize
y_scaler = MinMaxScaler()
y_scaler.fit(np.log(y_train))

y_train_scaled = y_scaler.transform(np.log(y_train))
y_test_scaled = y_scaler.transform(np.log(y_test))
y_val_scaled = y_scaler.transform(np.log(y_val))

# %% [markdown]
# ## model

# %%
input_shape = X_train.shape[1:]
output_shape = y_train_scaled.shape[1]
reg = regularizers.l1_l2(l1=0.04, l2=0.02)

# %%
# instantiate model
model = Sequential()

# masking 
# model.add(Masking(input_shape = input_shape))

# hidden layer architecture
model.add(LSTM(200, return_sequences=True,\
              input_shape = input_shape))

model.add(LSTM(150, return_sequences=True, 
               recurrent_regularizer=reg
              ))

model.add(LSTM(150, return_sequences=True, 
               recurrent_regularizer=reg
              ))

model.add(LSTM(150, return_sequences=True, 
               recurrent_regularizer=reg
              ))

# pass final sequences
model.add(LSTM(200, return_sequences=False))

# prediction layer
model.add(Dense(output_shape, activation = 'linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 56, 200)           165600
#
#  lstm_1 (LSTM)               (None, 56, 150)           210600
#
#  lstm_2 (LSTM)               (None, 56, 150)           180600
#
#  lstm_3 (LSTM)               (None, 56, 150)           180600
#
#  lstm_4 (LSTM)               (None, 200)               280800
#
#  dense (Dense)               (None, 7)                 1407
#
# =================================================================
# Total params: 1019607 (3.89 MB)
# Trainable params: 1019607 (3.89 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
optimizer = Nadam(learning_rate=0.00003, 
                  beta_1=0.8,
                  epsilon=1e-18)

# %%
model.compile(
    loss=['mae'], 
    metrics=['mae'],
    optimizer=optimizer
)

es = EarlyStopping(
    patience=10, 
    restore_best_weights=True
)

history = model.fit(
                X_train, 
                y_train_scaled, 
                batch_size = 16, 
                epochs = 100,
                shuffle = False,
                verbose = 2,
                validation_data = (X_val, y_val_scaled), 
                callbacks=[es]
)
# Out:
# Epoch 1/100
# 4/4 - 4s - loss: 361.1138 - mae: 0.5278 - val_loss: 360.4353 - val_mae: 0.7072 - 4s/epoch - 1s/step
# Epoch 2/100
# 4/4 - 0s - loss: 359.9350 - mae: 0.5257 - val_loss: 359.2242 - val_mae: 0.7045 - 422ms/epoch - 106ms/step
# Epoch 3/100
# 4/4 - 0s - loss: 358.7013 - mae: 0.5234 - val_loss: 357.9431 - val_mae: 0.7014 - 437ms/epoch - 109ms/step
# Epoch 4/100
# 4/4 - 0s - loss: 357.4111 - mae: 0.5208 - val_loss: 356.6335 - val_mae: 0.6977 - 422ms/epoch - 105ms/step
# Epoch 5/100
# 4/4 - 0s - loss: 356.0986 - mae: 0.5177 - val_loss: 355.3137 - val_mae: 0.6933 - 435ms/epoch - 109ms/step
# Epoch 6/100
# 4/4 - 0s - loss: 354.7786 - mae: 0.5140 - val_loss: 353.9907 - val_mae: 0.6877 - 435ms/epoch - 109ms/step
# Epoch 7/100
# 4/4 - 0s - loss: 353.4568 - mae: 0.5093 - val_loss: 352.6671 - val_mae: 0.6804 - 430ms/epoch - 107ms/step
# Epoch 8/100
# 4/4 - 0s - loss: 352.1349 - mae: 0.5032 - val_loss: 351.3435 - val_mae: 0.6708 - 429ms/epoch - 107ms/step
# Epoch 9/100
# 4/4 - 0s - loss: 350.8137 - mae: 0.4952 - val_loss: 350.0190 - val_mae: 0.6574 - 427ms/epoch - 107ms/step
# Epoch 10/100
# 4/4 - 0s - loss: 349.4922 - mae: 0.4841 - val_loss: 348.6917 - val_mae: 0.6381 - 445ms/epoch - 111ms/step
# Epoch 11/100
# 4/4 - 0s - loss: 348.1692 - mae: 0.4682 - val_loss: 347.3575 - val_mae: 0.6089 - 441ms/epoch - 110ms/step
# Epoch 12/100
# 4/4 - 0s - loss: 346.8409 - mae: 0.4439 - val_loss: 346.0080 - val_mae: 0.5613 - 431ms/epoch - 108ms/step
# Epoch 13/100
# 4/4 - 0s - loss: 345.4996 - mae: 0.4038 - val_loss: 344.6230 - val_mae: 0.4748 - 444ms/epoch - 111ms/step
# Epoch 14/100
# 4/4 - 0s - loss: 344.1277 - mae: 0.3295 - val_loss: 343.1539 - val_mae: 0.3008 - 446ms/epoch - 112ms/step
# Epoch 15/100
# 4/4 - 0s - loss: 342.7294 - mae: 0.2254 - val_loss: 341.8227 - val_mae: 0.2620 - 434ms/epoch - 108ms/step
# Epoch 16/100
# 4/4 - 0s - loss: 341.4152 - mae: 0.2028 - val_loss: 340.5225 - val_mae: 0.2508 - 445ms/epoch - 111ms/step
# Epoch 17/100
# 4/4 - 0s - loss: 340.1090 - mae: 0.1847 - val_loss: 339.2481 - val_mae: 0.2623 - 434ms/epoch - 109ms/step
# Epoch 18/100
# 4/4 - 0s - loss: 338.8150 - mae: 0.1757 - val_loss: 337.9297 - val_mae: 0.2265 - 423ms/epoch - 106ms/step
# Epoch 19/100
# 4/4 - 0s - loss: 337.5215 - mae: 0.1640 - val_loss: 336.6600 - val_mae: 0.2363 - 431ms/epoch - 108ms/step
# Epoch 20/100
# 4/4 - 0s - loss: 336.2380 - mae: 0.1592 - val_loss: 335.3849 - val_mae: 0.2375 - 438ms/epoch - 109ms/step
# Epoch 21/100
# 4/4 - 0s - loss: 334.9583 - mae: 0.1549 - val_loss: 334.0976 - val_mae: 0.2233 - 437ms/epoch - 109ms/step
# Epoch 22/100
# 4/4 - 0s - loss: 333.6818 - mae: 0.1505 - val_loss: 332.8354 - val_mae: 0.2308 - 435ms/epoch - 109ms/step
# Epoch 23/100
# 4/4 - 0s - loss: 332.4105 - mae: 0.1481 - val_loss: 331.5422 - val_mae: 0.2043 - 433ms/epoch - 108ms/step
# Epoch 24/100
# 4/4 - 0s - loss: 331.1411 - mae: 0.1445 - val_loss: 330.3056 - val_mae: 0.2311 - 455ms/epoch - 114ms/step
# Epoch 25/100
# 4/4 - 0s - loss: 329.8781 - mae: 0.1440 - val_loss: 329.0075 - val_mae: 0.1930 - 465ms/epoch - 116ms/step
# Epoch 26/100
# 4/4 - 0s - loss: 328.6169 - mae: 0.1419 - val_loss: 327.7826 - val_mae: 0.2248 - 450ms/epoch - 113ms/step
# Epoch 27/100
# 4/4 - 0s - loss: 327.3604 - mae: 0.1412 - val_loss: 326.5026 - val_mae: 0.1982 - 462ms/epoch - 116ms/step
# Epoch 28/100
# 4/4 - 0s - loss: 326.1060 - mae: 0.1394 - val_loss: 325.2807 - val_mae: 0.2266 - 469ms/epoch - 117ms/step
# Epoch 29/100
# 4/4 - 0s - loss: 324.8573 - mae: 0.1402 - val_loss: 323.9943 - val_mae: 0.1872 - 448ms/epoch - 112ms/step
# Epoch 30/100
# 4/4 - 0s - loss: 323.6099 - mae: 0.1388 - val_loss: 322.7833 - val_mae: 0.2202 - 462ms/epoch - 116ms/step
# Epoch 31/100
# 4/4 - 0s - loss: 322.3666 - mae: 0.1386 - val_loss: 321.5139 - val_mae: 0.1912 - 450ms/epoch - 112ms/step
# Epoch 32/100
# 4/4 - 0s - loss: 321.1256 - mae: 0.1372 - val_loss: 320.3042 - val_mae: 0.2190 - 469ms/epoch - 117ms/step
# Epoch 33/100
# 4/4 - 0s - loss: 319.8898 - mae: 0.1380 - val_loss: 319.0343 - val_mae: 0.1833 - 466ms/epoch - 116ms/step
# Epoch 34/100
# 4/4 - 0s - loss: 318.6555 - mae: 0.1371 - val_loss: 317.8370 - val_mae: 0.2172 - 464ms/epoch - 116ms/step
# Epoch 35/100
# 4/4 - 0s - loss: 317.4253 - mae: 0.1372 - val_loss: 316.5736 - val_mae: 0.1815 - 464ms/epoch - 116ms/step
# Epoch 36/100
# 4/4 - 0s - loss: 316.1977 - mae: 0.1365 - val_loss: 315.3836 - val_mae: 0.2163 - 462ms/epoch - 115ms/step
# Epoch 37/100
# 4/4 - 0s - loss: 314.9742 - mae: 0.1368 - val_loss: 314.1210 - val_mae: 0.1749 - 457ms/epoch - 114ms/step
# Epoch 38/100
# 4/4 - 0s - loss: 313.7534 - mae: 0.1365 - val_loss: 312.9391 - val_mae: 0.2115 - 476ms/epoch - 119ms/step
# Epoch 39/100
# 4/4 - 0s - loss: 312.5351 - mae: 0.1358 - val_loss: 311.7061 - val_mae: 0.1938 - 464ms/epoch - 116ms/step
# Epoch 40/100
# 4/4 - 0s - loss: 311.3194 - mae: 0.1345 - val_loss: 310.5031 - val_mae: 0.2028 - 460ms/epoch - 115ms/step
# Epoch 41/100
# 4/4 - 0s - loss: 310.1085 - mae: 0.1348 - val_loss: 309.2898 - val_mae: 0.1983 - 451ms/epoch - 113ms/step
# Epoch 42/100
# 4/4 - 0s - loss: 308.9005 - mae: 0.1346 - val_loss: 308.0918 - val_mae: 0.2058 - 467ms/epoch - 117ms/step
# Epoch 43/100
# 4/4 - 0s - loss: 307.6964 - mae: 0.1352 - val_loss: 306.8590 - val_mae: 0.1753 - 461ms/epoch - 115ms/step
# Epoch 44/100
# 4/4 - 0s - loss: 306.4952 - mae: 0.1355 - val_loss: 305.6925 - val_mae: 0.2081 - 467ms/epoch - 117ms/step
# Epoch 45/100
# 4/4 - 0s - loss: 305.2963 - mae: 0.1349 - val_loss: 304.4790 - val_mae: 0.1905 - 467ms/epoch - 117ms/step
# Epoch 46/100
# 4/4 - 0s - loss: 304.1002 - mae: 0.1340 - val_loss: 303.2990 - val_mae: 0.2033 - 464ms/epoch - 116ms/step
# Epoch 47/100
# 4/4 - 0s - loss: 302.9086 - mae: 0.1344 - val_loss: 302.1006 - val_mae: 0.1946 - 469ms/epoch - 117ms/step
# Epoch 48/100
# 4/4 - 0s - loss: 301.7194 - mae: 0.1340 - val_loss: 300.9218 - val_mae: 0.2023 - 454ms/epoch - 114ms/step
# Epoch 49/100
# 4/4 - 0s - loss: 300.5342 - mae: 0.1344 - val_loss: 299.7084 - val_mae: 0.1721 - 459ms/epoch - 115ms/step
# Epoch 50/100
# 4/4 - 0s - loss: 299.3524 - mae: 0.1350 - val_loss: 298.5617 - val_mae: 0.2056 - 478ms/epoch - 119ms/step
# Epoch 51/100
# 4/4 - 0s - loss: 298.1724 - mae: 0.1342 - val_loss: 297.3664 - val_mae: 0.1870 - 467ms/epoch - 117ms/step
# Epoch 52/100
# 4/4 - 0s - loss: 296.9956 - mae: 0.1333 - val_loss: 296.2058 - val_mae: 0.2001 - 455ms/epoch - 114ms/step
# Epoch 53/100
# 4/4 - 0s - loss: 295.8231 - mae: 0.1336 - val_loss: 295.0374 - val_mae: 0.2022 - 469ms/epoch - 117ms/step
# Epoch 54/100
# 4/4 - 0s - loss: 294.6536 - mae: 0.1339 - val_loss: 293.8437 - val_mae: 0.1757 - 464ms/epoch - 116ms/step
# Epoch 55/100
# 4/4 - 0s - loss: 293.4871 - mae: 0.1337 - val_loss: 292.7094 - val_mae: 0.2055 - 474ms/epoch - 118ms/step
# Epoch 56/100
# 4/4 - 0s - loss: 292.3245 - mae: 0.1343 - val_loss: 291.5198 - val_mae: 0.1767 - 473ms/epoch - 118ms/step
# Epoch 57/100
# 4/4 - 0s - loss: 291.1636 - mae: 0.1333 - val_loss: 290.3826 - val_mae: 0.1973 - 469ms/epoch - 117ms/step
# Epoch 58/100
# 4/4 - 0s - loss: 290.0066 - mae: 0.1331 - val_loss: 289.2306 - val_mae: 0.1997 - 471ms/epoch - 118ms/step
# Epoch 59/100
# 4/4 - 0s - loss: 288.8533 - mae: 0.1334 - val_loss: 288.0592 - val_mae: 0.1795 - 492ms/epoch - 123ms/step
# Epoch 60/100
# 4/4 - 0s - loss: 287.7024 - mae: 0.1330 - val_loss: 286.9351 - val_mae: 0.2037 - 480ms/epoch - 120ms/step
# Epoch 61/100
# 4/4 - 0s - loss: 286.5559 - mae: 0.1340 - val_loss: 285.7545 - val_mae: 0.1682 - 474ms/epoch - 118ms/step
# Epoch 62/100
# 4/4 - 0s - loss: 285.4114 - mae: 0.1337 - val_loss: 284.6352 - val_mae: 0.1911 - 478ms/epoch - 119ms/step
# Epoch 63/100
# 4/4 - 0s - loss: 284.2688 - mae: 0.1324 - val_loss: 283.4834 - val_mae: 0.1784 - 466ms/epoch - 116ms/step
# Epoch 64/100
# 4/4 - 0s - loss: 283.1305 - mae: 0.1324 - val_loss: 282.3648 - val_mae: 0.1957 - 466ms/epoch - 117ms/step
# Epoch 65/100
# 4/4 - 0s - loss: 281.9957 - mae: 0.1326 - val_loss: 281.2215 - val_mae: 0.1850 - 462ms/epoch - 115ms/step
# Epoch 66/100
# 4/4 - 0s - loss: 280.8634 - mae: 0.1320 - val_loss: 280.0831 - val_mae: 0.1761 - 480ms/epoch - 120ms/step
# Epoch 67/100
# 4/4 - 0s - loss: 279.7350 - mae: 0.1322 - val_loss: 278.9846 - val_mae: 0.2041 - 465ms/epoch - 116ms/step
# Epoch 68/100
# 4/4 - 0s - loss: 278.6109 - mae: 0.1338 - val_loss: 277.8307 - val_mae: 0.1734 - 472ms/epoch - 118ms/step
# Epoch 69/100
# 4/4 - 0s - loss: 277.4866 - mae: 0.1321 - val_loss: 276.7303 - val_mae: 0.1933 - 477ms/epoch - 119ms/step
# Epoch 70/100
# 4/4 - 0s - loss: 276.3673 - mae: 0.1321 - val_loss: 275.5948 - val_mae: 0.1749 - 473ms/epoch - 118ms/step
# Epoch 71/100
# 4/4 - 0s - loss: 275.2509 - mae: 0.1321 - val_loss: 274.5073 - val_mae: 0.2014 - 474ms/epoch - 119ms/step
# Epoch 72/100
# 4/4 - 0s - loss: 274.1391 - mae: 0.1334 - val_loss: 273.3658 - val_mae: 0.1708 - 479ms/epoch - 120ms/step
# Epoch 73/100
# 4/4 - 0s - loss: 273.0280 - mae: 0.1322 - val_loss: 272.2792 - val_mae: 0.1918 - 471ms/epoch - 118ms/step
# Epoch 74/100
# 4/4 - 0s - loss: 271.9209 - mae: 0.1319 - val_loss: 271.1662 - val_mae: 0.1832 - 495ms/epoch - 124ms/step
# Epoch 75/100
# 4/4 - 0s - loss: 270.8167 - mae: 0.1312 - val_loss: 270.0638 - val_mae: 0.1821 - 473ms/epoch - 118ms/step
# Epoch 76/100
# 4/4 - 0s - loss: 269.7159 - mae: 0.1310 - val_loss: 268.9559 - val_mae: 0.1724 - 485ms/epoch - 121ms/step
# Epoch 77/100
# 4/4 - 0s - loss: 268.6193 - mae: 0.1317 - val_loss: 267.8873 - val_mae: 0.1989 - 461ms/epoch - 115ms/step
# Epoch 78/100
# 4/4 - 0s - loss: 267.5260 - mae: 0.1327 - val_loss: 266.7651 - val_mae: 0.1686 - 459ms/epoch - 115ms/step
# Epoch 79/100
# 4/4 - 0s - loss: 266.4341 - mae: 0.1318 - val_loss: 265.6981 - val_mae: 0.1904 - 470ms/epoch - 118ms/step
# Epoch 80/100
# 4/4 - 0s - loss: 265.3459 - mae: 0.1315 - val_loss: 264.5893 - val_mae: 0.1671 - 468ms/epoch - 117ms/step
# Epoch 81/100
# 4/4 - 0s - loss: 264.2616 - mae: 0.1319 - val_loss: 263.5363 - val_mae: 0.1965 - 468ms/epoch - 117ms/step
# Epoch 82/100
# 4/4 - 0s - loss: 263.1805 - mae: 0.1323 - val_loss: 262.4281 - val_mae: 0.1673 - 475ms/epoch - 119ms/step
# Epoch 83/100
# 4/4 - 0s - loss: 262.1017 - mae: 0.1317 - val_loss: 261.3733 - val_mae: 0.1886 - 473ms/epoch - 118ms/step
# Epoch 84/100
# 4/4 - 0s - loss: 261.0261 - mae: 0.1314 - val_loss: 260.2929 - val_mae: 0.1812 - 471ms/epoch - 118ms/step
# Epoch 85/100
# 4/4 - 0s - loss: 259.9533 - mae: 0.1307 - val_loss: 259.2206 - val_mae: 0.1788 - 471ms/epoch - 118ms/step
# Epoch 86/100
# 4/4 - 0s - loss: 258.8841 - mae: 0.1306 - val_loss: 258.1459 - val_mae: 0.1707 - 475ms/epoch - 119ms/step
# Epoch 87/100
# 4/4 - 0s - loss: 257.8188 - mae: 0.1309 - val_loss: 257.0998 - val_mae: 0.1881 - 459ms/epoch - 115ms/step
# Epoch 88/100
# 4/4 - 0s - loss: 256.7560 - mae: 0.1309 - val_loss: 256.0157 - val_mae: 0.1644 - 471ms/epoch - 118ms/step
# Epoch 89/100
# 4/4 - 0s - loss: 255.6973 - mae: 0.1317 - val_loss: 254.9873 - val_mae: 0.1934 - 458ms/epoch - 115ms/step
# Epoch 90/100
# 4/4 - 0s - loss: 254.6406 - mae: 0.1316 - val_loss: 253.9114 - val_mae: 0.1717 - 473ms/epoch - 118ms/step
# Epoch 91/100
# 4/4 - 0s - loss: 253.5863 - mae: 0.1306 - val_loss: 252.8680 - val_mae: 0.1794 - 470ms/epoch - 117ms/step
# Epoch 92/100
# 4/4 - 0s - loss: 252.5356 - mae: 0.1302 - val_loss: 251.8283 - val_mae: 0.1876 - 482ms/epoch - 121ms/step
# Epoch 93/100
# 4/4 - 0s - loss: 251.4891 - mae: 0.1308 - val_loss: 250.7596 - val_mae: 0.1638 - 485ms/epoch - 121ms/step
# Epoch 94/100
# 4/4 - 0s - loss: 250.4457 - mae: 0.1314 - val_loss: 249.7472 - val_mae: 0.1934 - 475ms/epoch - 119ms/step
# Epoch 95/100
# 4/4 - 0s - loss: 249.4045 - mae: 0.1313 - val_loss: 248.6806 - val_mae: 0.1655 - 484ms/epoch - 121ms/step
# Epoch 96/100
# 4/4 - 0s - loss: 248.3661 - mae: 0.1307 - val_loss: 247.6738 - val_mae: 0.1943 - 481ms/epoch - 120ms/step
# Epoch 97/100
# 4/4 - 0s - loss: 247.3320 - mae: 0.1314 - val_loss: 246.6109 - val_mae: 0.1636 - 478ms/epoch - 120ms/step
# Epoch 98/100
# 4/4 - 0s - loss: 246.3000 - mae: 0.1309 - val_loss: 245.5922 - val_mae: 0.1743 - 485ms/epoch - 121ms/step
# Epoch 99/100
# 4/4 - 0s - loss: 245.2705 - mae: 0.1300 - val_loss: 244.5753 - val_mae: 0.1838 - 472ms/epoch - 118ms/step
# Epoch 100/100
# 4/4 - 0s - loss: 244.2452 - mae: 0.1301 - val_loss: 243.5319 - val_mae: 0.1634 - 478ms/epoch - 120ms/step

# %% [markdown]
# # Predict

# %%
y_pred = model.predict(X_test)

y_pred = y_scaler.inverse_transform(y_pred)
y_pred = np.exp(y_pred)
# Out:
# 1/1 [==============================] - 1s 792ms/step

# %%
for i in range(y_pred.shape[0]):
    fig = plt.gcf(); fig.set_size_inches(20, 12);
    plt.plot(y_pred[i, :], c="blue", label="Prediction")
    plt.plot(y_test[i, :], c="red", label="Test")
#     plt.ylim(0, 430)
    plt.legend(loc='upper right')
    plt.show();

# %%
dl_error = np.mean(abs(y_pred - y_test))

# %%
base_error = np.mean(abs((df[['nb_cars']]-df[['nb_cars']].shift(7)).dropna()))[0]
base_error
# Out:
# /Users/reinisbrezinskis/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# 212.9205921938089

# %%
print(
    f"DL model predicts with an average error of        {round(dl_error, 2)} cars"
    "\n"
    f"1 Week before predicts with an average error of  {round(base_error, 2)} cars"
)
# Out:
# DL model predicts with an average error of        386.58 cars
# 1 Week before predicts with an average error of  212.92 cars

# %%
def plot_history(history):
    
    fig, ax = plt.subplots(1,2, figsize=(20,7))
    # --- LOSS: LOSS --- 
    ax[0].plot(history.history['loss'])
    ax[0].plot(history.history['val_loss'])
    ax[0].set_title('Loss')
    ax[0].set_ylabel('LOSS')
    ax[0].set_xlabel('EPOCH')
    ax[0].legend(['Train', 'Validation'], loc='best')
    ax[0].grid(axis="x",linewidth=0.5)
    ax[0].grid(axis="y",linewidth=0.5)
    
    # --- METRICS: MAE ---
    
    ax[1].plot(history.history['mae'])
    ax[1].plot(history.history['val_mae'])
    ax[1].set_title('Mean Absolute Error')
    ax[1].set_ylabel('LOSS')
    ax[1].set_xlabel('EPOCH')
    ax[1].legend(['Train', 'Validation'], loc='best')
    ax[1].grid(axis="x",linewidth=0.5)
    ax[1].grid(axis="y",linewidth=0.5)
                        
    return ax

# %%
plot_history(history);
